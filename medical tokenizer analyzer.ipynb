# %% [markdown]
# <a href="https://colab.research.google.com/github/asmasaeed18as/medical-tokenizer-analysis-/blob/main/medical%20tokenizer%20analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p notebooks data results/figures results/tables src

# %%
# !mv medical tokenizer analyzer.ipynb notebooks/
# Out:
# mv: cannot stat 'medical': No such file or directory
# mv: cannot stat 'tokenizer': No such file or directory
# mv: cannot stat 'analyzer.ipynb': No such file or directory
